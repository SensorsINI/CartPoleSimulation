# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
with open("Experiment.csv") as f:
    datanames = f.readlines()[54]
print(datanames)
# Out:
# time,angle,angleD,angleDD,angle_cos,angle_sin,position,positionD,positionDD,Q,u,target_position

# %%
dataRNN = np.genfromtxt("Experiment-2.csv", skip_header = 56, delimiter=",")
#dataDNN = np.genfromtxt("Experiment-3.csv", skip_header = 56, delimiter=",")
time = dataRNN[:,0]
angleRNN = dataRNN[:,1]
#angleDNN = dataDNN[:,1]

# %%
plt.figure()
plt.plot(time, angleRNN)
plt.show()
